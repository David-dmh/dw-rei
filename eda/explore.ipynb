# %%
import pickle

# %%
with open(r"C:\Users\User\Documents\FINANCES_CAREER\ONLINE_BUSINESS\Backend_API_v2\data\sample_listings_2022-03-01_ACT.txt", "rb") as f:
    listings = pickle.load(f)
    
# print(listings[720])
print(listings[741])
# print(listings[778])
# Out:
# {'suburb': 'Taylor', 'state': 'ACT', 'postcode': '2913', 'full_address': '55 Corkery Crescent, Taylor, ACT 2913', 'price': 649000, 'bedrooms': 2, 'bathrooms': 1, 'parking_spaces': 1, 'building_size': '121.5', 'building_size_unit': 'm²', 'land_size': 135.0, 'land_size_unit': 'm²', 'listing_company_name': 'Independent Property Group Gungahlin - GUNGAHLIN', 'sold_date': None, 'description': "Open for inspection this Saturday for the general public from 11.00am - 1.00pm at 2/24 Ernest Cavanagh Street, GungahlinAn MBA accomplished builder, Sunny Homes, is proud to present these beautiful separate title homes in Corkery Crescent, Taylor.  Corkery Crescent nestled in Taylor is a stylish, affordable precinct in this leafy suburb representing a rewarding lifestyle representing a fusion of contemporary comfort with nature's bounty on your doorstep. The thoughtful contemporary design complements the natural environment of the surrounding area.This exclusive opportunity offers house & land split
# ...

# %%
"34/41 Arthur Blakeley Way, Coombs, ACT 2611" == "34/41 Arthur Blakeley Way, Coombs, ACT 2611"
# Out:
# True

# %%
'c' in ['a', 'b']
# Out:
# False

# %%
'a' in ['a', 'b']
# Out:
# True

# %%
[listing["full_address"] for listing in listings]
# Out:
# ['34/41 Arthur Blakeley Way, Coombs, ACT 2611',
#  '2/35 Torrens, Braddon, ACT 2612',
#  '6A Arndell Street, Macquarie, ACT 2614',
#  '83/121 Thynne Street, Bruce, ACT 2617',
#  '13 Kidman Close, Kambah, ACT 2902',
#  '39 Braybrooke St, Bruce, ACT 2617',
#  '108 Monaro Crescent, Red Hill, ACT 2603',
#  '3 Barunga Street, Ngunnawal, ACT 2913',
#  '64 Onkaparinga Crescent, Kaleen, ACT 2617',
#  '25 Ruth Bedford Street, Franklin, ACT 2913',
#  '90 Swain Street, Gungahlin, ACT 2912',
#  '109 Bernard Heinze Avenue, Moncrieff, ACT 2914',
#  '5/5 Garran Place, Garran, ACT 2605',
#  '4 Selleck Street, Casey, ACT 2913',
#  '18 Burnum Burnum Close, Bonner, ACT 2914',
#  '4 Cameron Street, Farrer, ACT 2607',
#  '25/47 Blackall Street, Barton, ACT 2600',
#  '233 Antill Street, Watson, ACT 2602',
#  '5/28 Watson Street, Turner, ACT 2612',
#  '14 The Pines Avenue, Symonston, ACT 2609',
#  '27 Ayrton Street, Gungahlin, ACT 2912',
#  '6 Middleton Circuit, Gowrie, ACT 2904',
# ...

# %%
listings
# Out:
# [{'suburb': 'Coombs',
#   'state': 'ACT',
#   'postcode': '2611',
#   'full_address': '34/41 Arthur Blakeley Way, Coombs, ACT 2611',
#   'price': None,
#   'bedrooms': 2,
#   'bathrooms': 2,
#   'parking_spaces': 1,
#   'building_size': '120',
#   'building_size_unit': 'm²',
#   'land_size': -1.0,
#   'land_size_unit': None,
#   'listing_company_name': 'Blackshaw Weston Creek Molonglo - WESTON',
#   'sold_date': None,
# ...

# %%
float("1, 500, 000".replace(",", "").replace(" ", ""))
# Out:
# 1500000.0

# %%
listings[0].keys()
# Out:
# dict_keys(['suburb', 'state', 'postcode', 'full_address', 'price', 'bedrooms', 'bathrooms', 'parking_spaces', 'building_size', 'building_size_unit', 'land_size', 'land_size_unit', 'listing_company_name', 'sold_date', 'description', 'listing_download_date'])
